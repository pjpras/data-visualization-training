# %%
import pandas as pd
import matplotlib.pyplot as plt

data = [10, 20, 30, 40, 50]
months = ['january', 'february', 'march', 'april', 'may', 'june',
          'july', 'august', 'september', 'october', 'november', 'december']
sales_data = [10000, 12000, 14000, 13000, 15000,
              16000, 17000, 18000, 19000, 20000, 21000, 22000]
series = pd.Series(data)
sales_series = pd.Series(data=sales_data, index=months,
                         name='Sales Data (USD)')
print(type(series))
print(sales_series)


data = {
    'Name': ['Pratham', 'Rahul', 'Rohit', 'Rajesh'],
    'Age': [21, 22, 23, 24],
    'City': ['Mumbai', 'Delhi', 'Bangalore', 'Chennai']
}

df = pd.DataFrame(data)

new_columns = {'Gender': ['M', 'M', 'M', 'M'],
               'Grade': ['A', 'B', 'C', 'D']}

df['Gender'] = new_columns['Gender']
df['Grade'] = new_columns['Grade']
df = pd.concat([df, pd.DataFrame(new_columns)], ignore_index=True, axis=1)

df.insert(1, 'Country', ['India', 'India', 'India', 'India'])
print(df)

x = [1, 2, 3, 4, 5]
y = [10, 20, 30, 40, 50]
plt.plot(x, y)
plt.xlabel("X") 
plt.ylabel("Y") 
plt.savefig('LineChart.png')
plt.show()
# Out:
# <class 'pandas.core.series.Series'>
# january      10000
# february     12000
# march        14000
# april        13000
# may          15000
# june         16000
# july         17000
# august       18000
# september    19000
# october      20000
# november     21000
# december     22000
# Name: Sales Data (USD), dtype: int64
#          0 Country   1          2  3  4  5  6
# 0  Pratham   India  21     Mumbai  M  A  M  A
# 1    Rahul   India  22      Delhi  M  B  M  B
# 2    Rohit   India  23  Bangalore  M  C  M  C
# 3   Rajesh   India  24    Chennai  M  D  M  D

# %%
import pandas as pd

data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Age': [21, 22, 23, 24],
    'City': ['Mumbai', 'Delhi', 'Bangalore', 'Chennai']
}
print("Initial Data Frame")

df = pd.DataFrame(data)
print(df)

new_rows = pd.DataFrame([{
    'Name':'Eve',
    'Age': 25,
    'City':'Hyderabad'
},{
    'Name':'Frank',
    'Age': 26,
    'City':'Kolkata'
},{
    'Name':'George',
    'Age': 27,
    'City':'Pune'
},{
    'Name':'Harry',
    'Age': 28,
    'City':'Jaipur'
}])

df = pd.concat([df,new_rows], ignore_index=True, axis=0)
print('After adding new rows')

new_row = {'Name':'Dan','Age':29,'City':'Noida'}
df.loc[3] = new_row
print(df)

df = df.rename(columns={'Name':'Full Name','Age':'Student Age','City':'Student City'})

print(data)

df.columns = df.columns.str.lower()
print(df)

df.loc[1] = {'full name':'Sanjay'}
print(df)

df.loc[1:3,['full name','student city']]
# Out:
# Initial Data Frame
#       Name  Age       City
# 0    Alice   21     Mumbai
# 1      Bob   22      Delhi
# 2  Charlie   23  Bangalore
# 3    David   24    Chennai
# After adding new rows
#       Name  Age       City
# 0    Alice   21     Mumbai
# 1      Bob   22      Delhi
# 2  Charlie   23  Bangalore
# 3      Dan   29      Noida
# 4      Eve   25  Hyderabad
# 5    Frank   26    Kolkata
# 6   George   27       Pune
# 7    Harry   28     Jaipur
# {'Name': ['Alice', 'Bob', 'Charlie', 'David'], 'Age': [21, 22, 23, 24], 'City': ['Mumbai', 'Delhi', 'Bangalore', 'Chennai']}
#   full name  student age student city
# 0     Alice           21       Mumbai
# 1       Bob           22        Delhi
# 2   Charlie           23    Bangalore
# 3       Dan           29        Noida
# 4       Eve           25    Hyderabad
# 5     Frank           26      Kolkata
# 6    George           27         Pune
# 7     Harry           28       Jaipur
#   full name  student age student city
# 0     Alice         21.0       Mumbai
# 1    Sanjay          NaN          NaN
# 2   Charlie         23.0    Bangalore
# 3       Dan         29.0        Noida
# 4       Eve         25.0    Hyderabad
# 5     Frank         26.0      Kolkata
# 6    George         27.0         Pune
# 7     Harry         28.0       Jaipur
#   full name student city
# 1    Sanjay          NaN
# 2   Charlie    Bangalore
# 3       Dan        Noida

# %%
fruit_data = {"Fruit" : ["Apple", "Banana", "Mango", "Orange", "Pineapple"],
                "Price" : [100, 50, 60, 40, 30],
                'Colour': ['Red', 'Yellow', 'Yellow', 'Orange', 'Yellow']}

data = pd.DataFrame(fruit_data)
print("Original Data")
print(data)

data.loc[data['Price'] > 50, 'Remarks'] = 'Expensive'
data.loc[data['Price'] <= 50, 'Remarks'] = 'Not Expensive'

print("Data after adding Remarks")
print(data)
# Out:
# Original Data
#        Fruit  Price  Colour
# 0      Apple    100     Red
# 1     Banana     50  Yellow
# 2      Mango     60  Yellow
# 3     Orange     40  Orange
# 4  Pineapple     30  Yellow
# Data after adding Remarks
#        Fruit  Price  Colour        Remarks
# 0      Apple    100     Red      Expensive
# 1     Banana     50  Yellow  Not Expensive
# 2      Mango     60  Yellow      Expensive
# 3     Orange     40  Orange  Not Expensive
# 4  Pineapple     30  Yellow  Not Expensive
# /var/folders/hj/lz0bq8mn5mvcrwft0knrgr8r0000gn/T/ipykernel_4952/1276634971.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Expensive' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   data.loc[data['Price'] > 50, 'Remarks'] = 'Expensive'

# %%
data = {"Employee ID": [101, 102, 103, 104, 105],"Name" : ["Alice", "Bob", "Charlie", "David", "Eve"],"Age": [21, 22, 23, 24, 25],"City": ["Mumbai", "Delhi", "Bangalore", "Chennai", "Hyderabad"]}
df = pd.DataFrame(data)
print("Initial Data Frame")
print(df)
employee_to_delete = "Charlie"
df = df[df['Name'] != employee_to_delete]
print("Data after deleting employee")
print(df)
# Out:
# Initial Data Frame
#    Employee ID     Name  Age       City
# 0          101    Alice   21     Mumbai
# 1          102      Bob   22      Delhi
# 2          103  Charlie   23  Bangalore
# 3          104    David   24    Chennai
# 4          105      Eve   25  Hyderabad
# Data after deleting employee
#    Employee ID   Name  Age       City
# 0          101  Alice   21     Mumbai
# 1          102    Bob   22      Delhi
# 3          104  David   24    Chennai
# 4          105    Eve   25  Hyderabad

# %%
data = pd.DataFrame({
    'Order ID': [101, 102, 103, 104, 105],
    'Product Name': ['Laptop', 'Mobile', 'Tablet', 'Monitor', 'Keyboard'],
    'Quantity': [10, 20, 30, 40, 50],
    'Status': ['Delivered', 'Cancelled', 'Delivered', 'Pending', 'Delivered']
})

data = data[data['Status'] != 'Cancelled']
print(data)
# Out:
#    Order ID Product Name  Quantity     Status
# 0       101       Laptop        10  Delivered
# 2       103       Tablet        30  Delivered
# 3       104      Monitor        40    Pending
# 4       105     Keyboard        50  Delivered

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Age': [21, 22, 23, 24],
    'Address': ['Mumbai', 'Delhi', 'Bangalore', 'Chennai'],
    'Qualification': ['B.Tech', 'B.Com', 'B.Sc', 'B.A']   
}

df = pd.DataFrame(data)
print(df['Name'])
#
dict = {'a':[1,2,3,4,5],'b':[6,7,8,9,10]}
df = pd.DataFrame(dict)
print(df)
#
df['sum'] = df['a'] + df['b']
print(df)
df['sub'] = df['a'] - df['b']
print(df)
df['mul'] = df['a'] * df['b']
print(df)

data = {"name":['Sally','Mary','John'],
        'age':[25,30,35],
        'qualified':[True,False,True]}
df = pd.DataFrame(data)
df.pop('age')
del df["name"]
print(df)

df = pd.concat([df.iloc[:1],new_rows,df.iloc[1:]]).reset_index(drop=True)

print(df)
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# 3      David
# Name: Name, dtype: object
#    a   b
# 0  1   6
# 1  2   7
# 2  3   8
# 3  4   9
# 4  5  10
#    a   b  sum
# 0  1   6    7
# 1  2   7    9
# 2  3   8   11
# 3  4   9   13
# 4  5  10   15
#    a   b  sum  sub
# 0  1   6    7   -5
# 1  2   7    9   -5
# 2  3   8   11   -5
# 3  4   9   13   -5
# 4  5  10   15   -5
#    a   b  sum  sub  mul
# 0  1   6    7   -5    6
# 1  2   7    9   -5   14
# 2  3   8   11   -5   24
# 3  4   9   13   -5   36
# 4  5  10   15   -5   50
#    qualified
# 0       True
# 1      False
# 2       True
#   qualified    Name   Age       City
# 0      True     NaN   NaN        NaN
# 1       NaN     Eve  25.0  Hyderabad
# 2       NaN   Frank  26.0    Kolkata
# 3       NaN  George  27.0       Pune
# 4       NaN   Harry  28.0     Jaipur
# 5     False     NaN   NaN        NaN
# 6      True     NaN   NaN        NaN

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

"""
Lab1: Write a Pandas program to split the following data frame into groups based on Class and count the number of students in that particular class. 
Also generate a bar chart based on the result and explain the conclusion.
"""

student_data = pd.DataFrame({
    'school_code': ['s001', 's002', 's003', 's001', 's002', 's004'],
    'class': ['V', 'VI', 'VI', 'VI', 'V', 'VI'],
    'name': ['Alberto Franco', 'Gino Mcneill', 'Ryan Parkes', 'Eesha Hinton', 'Gino Mcneill', 'David Parkes'],
    'age': [12, 12, 13, 13, 14, 12],
    'height': [173, 192, 186, 167, 151, 159],
    'weight': [35, 32, 33, 30, 31, 32],
    'address': ['street1', 'street2', 'street3', 'street1', 'street2', 'street4']
})

# Group by 'class' and count the number of students
class_counts = student_data.groupby('class').size()

print("Lab1: Number of Students by Class")
print(class_counts)

# Generate bar chart
class_counts.plot(kind='bar', color='skyblue')
plt.title('Number of Students by Class')
plt.xlabel('Class')
plt.ylabel('Number of Students')
plt.xticks(rotation=0)
plt.show()

"""
Lab2: Write a Pandas program to split the following dataframe by school code and get mean, min, and max value of age for each school. 
Also generate a horizontal bar chart based on the result and explain the conclusion.
"""

student_data = pd.DataFrame({
    'school_code': ['s001', 's002', 's003', 's001', 's002', 's004'],
    'class': ['V', 'V', 'VI', 'VI', 'V', 'VI'],
    'name': ['Alberto Franco', 'Gino Mcneill', 'Ryan Parkes', 'Eesha Hinton', 'Gino Mcneill', 'David Parkes'],
    'age': [12, 12, 13, 13, 14, 12],
    'height': [173, 192, 186, 167, 151, 159],
    'weight': [35, 32, 33, 30, 31, 32],
    'address': ['street1', 'street2', 'street3', 'street1', 'street2', 'street4']
})

# Group by 'school_code' and calculate mean, min, and max age
age_stats = student_data.groupby('school_code')[
    'age'].agg(['mean', 'min', 'max'])

print("Lab2: Age Statistics by School Code")
print(age_stats)

# Generate horizontal bar chart
age_stats.plot(kind='barh', figsize=(10, 6))
plt.title('Age Statistics by School Code')
plt.xlabel('Age')
plt.ylabel('School Code')
plt.legend(title='Statistics')
plt.show()

"""
Lab3: Write a Pandas program to split a dataset, group by one column and get mean, min, and max values by group. 
Using the following dataset find the mean, min, and max values of purchase amount (purch_amt) group by customer id (customer_id). 
Also generate a line chart based on the result and explain the conclusion.
"""

orders_data = pd.DataFrame({
    'ord_no': [70001, 70009, 70002, 70004, 70007, 70005, 70008, 70010, 70003, 70012, 70011, 70013],
    'purch_amt': [150.5, 270.65, 65.26, 110.5, 948.5, 2400.6, 5760, 1983.43, 2480.4, 250.45, 75.29, 3045.6],
    'ord_date': ['2012-10-05', '2012-09-10', '2012-10-05', '2012-08-17', '2012-09-10', '2012-07-27', '2012-09-10', '2012-10-10', '2012-10-10', '2012-06-27', '2012-08-17', '2012-04-25'],
    'customer_id': [3005, 3001, 3002, 3009, 3005, 3007, 3002, 3004, 3009, 3008, 3003, 3002],
    'salesman_id': [5002, 5005, 5001, 5003, 5002, 5001, 5001, 5006, 5003, 5002, 5007, 5001]
})

# Group by 'customer_id' and calculate mean, min, and max purchase amount
purchase_stats = orders_data.groupby(
    'customer_id')['purch_amt'].agg(['mean', 'min', 'max'])

print("Lab3: Purchase Amount Statistics by Customer ID")
print(purchase_stats)

# Generate line chart
purchase_stats.plot(kind='line', marker='o', figsize=(10, 6))
plt.title('Purchase Amount Statistics by Customer ID')
plt.xlabel('Customer ID')
plt.ylabel('Purchase Amount')
plt.legend(title='Statistics')
plt.grid(True)
plt.show()

"""
Lab4: Write a Pandas program to split the following data frame into groups and calculate monthly purchase amount. 
Also generate a bar chart based on the result and explain the conclusion.
"""

df = pd.DataFrame({
    'ord_no': [70001, 70009, 70002, 70004, 70007, 70005, 70008, 70010, 70003, 70012, 70011, 70013],
    'purch_amt': [150.5, 270.65, 65.26, 110.5, 948.5, 2400.6, 5760, 1983.43, 2480.4, 250.45, 75.29, 3045.6],
    'ord_date': ['05-10-2012', '09-10-2012', '05-10-2012', '08-17-2012', '10-09-2012', '07-27-2012', '10-09-2012', '10-10-2012', '10-10-2012', '06-17-2012', '07-08-2012', '04-25-2012'],
    'customer_id': [3001, 3001, 3005, 3001, 3005, 3001, 3005, 3001, 3005, 3001, 3005, 3005],
    'salesman_id': [5002, 5005, 5001, 5003, 5002, 5001, 5001, 5006, 5003, 5002, 5007, 5001]
})

# Convert 'ord_date' to datetime and extract month-year
df['ord_date'] = pd.to_datetime(df['ord_date'], format='%m-%d-%Y')
df['month_year'] = df['ord_date'].dt.to_period('M')

# Group by 'month_year' and calculate total purchase amount
monthly_purchases = df.groupby('month_year')['purch_amt'].sum()

print("Lab4: Monthly Purchase Amount")
print(monthly_purchases)

# Generate bar chart
monthly_purchases.plot(kind='bar', color='lightcoral')
plt.title('Monthly Purchase Amount')
plt.xlabel('Month-Year')
plt.ylabel('Total Purchase Amount')
plt.xticks(rotation=45)
plt.show()
# Out:
# Lab1: Number of Students by Class
# class
# V     2
# VI    4
# dtype: int64
# Lab2: Age Statistics by School Code
#              mean  min  max
# school_code
# s001         12.5   12   13
# s002         13.0   12   14
# s003         13.0   13   13
# s004         12.0   12   12
# Lab3: Purchase Amount Statistics by Customer ID
#                     mean      min      max
# customer_id
# 3001          270.650000   270.65   270.65
# 3002         2956.953333    65.26  5760.00
# 3003           75.290000    75.29    75.29
# 3004         1983.430000  1983.43  1983.43
# 3005          549.500000   150.50   948.50
# 3007         2400.600000  2400.60  2400.60
# 3008          250.450000   250.45   250.45
# 3009         1295.450000   110.50  2480.40
# Lab4: Monthly Purchase Amount
# month_year
# 2012-04     3045.60
# 2012-05      215.76
# 2012-06      250.45
# 2012-07     2475.89
# 2012-08      110.50
# 2012-09      270.65
# 2012-10    11172.33
# Freq: M, Name: purch_amt, dtype: float64
